# %%
import pandas as pd

# %%
macro = pd.read_excel('US_Housing_Macro_Analysis.xlsx', sheet_name='Average Revenue of US Home sale')
macro
# Out:
#    Home Sales Revenue Unnamed: 1 Unnamed: 2 Unnamed: 3
# 0                 NaN        NaN        NaN        NaN
# 1         Annual Data        NaN        NaN        NaN
# 2                 NaN        NaN        NaN        NaN
# 3              Period    Median     Average    Average
# 4                1963   10080000   10808000        NaN
# ..                ...        ...        ...        ...
# 58               2017  198060300  235943700        NaN
# 59               2018  201388800  237545000        NaN
# 60               2019  219584500  262203700        NaN
# 61               2020  276931800  322141800        NaN
# 62               2021  306164100  357898200        NaN
#
# [63 rows x 4 columns]

# %%
macro = macro.iloc[3:]
macro
# Out:
#    Home Sales Revenue Unnamed: 1 Unnamed: 2 Unnamed: 3
# 3              Period    Median     Average    Average
# 4                1963   10080000   10808000        NaN
# 5                1964   10678500   11582500        NaN
# 6                1965   11500000   12362500        NaN
# 7                1966    9865400   10741300        NaN
# 8                1967   11054900   11980200        NaN
# 9                1968   12103000   13034000        NaN
# 10               1969   11468800   12499200        NaN
# 11               1970   11349000   12901000        NaN
# 12               1971   16531200   18564800        NaN
# 13               1972   19816800   21899000        NaN
# 14               1973   20605000   22507000        NaN
# 15               1974   18632100   20189100        NaN
# 16               1975   21575700   23387400        NaN
# 17               1976   28553200   31008000        NaN
# 18               1977   39967200   44389800        NaN
# ...

# %%
macro.drop(columns='Unnamed: 3', inplace= True)
macro
# Out:
# /var/folders/zq/0hmyg29903n1xkl833j8x3h00000gn/T/ipykernel_90756/3377252478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   macro.drop(columns='Unnamed: 3', inplace= True)
#    Home Sales Revenue Unnamed: 1 Unnamed: 2
# 3              Period    Median     Average
# 4                1963   10080000   10808000
# 5                1964   10678500   11582500
# 6                1965   11500000   12362500
# 7                1966    9865400   10741300
# 8                1967   11054900   11980200
# 9                1968   12103000   13034000
# 10               1969   11468800   12499200
# 11               1970   11349000   12901000
# 12               1971   16531200   18564800
# 13               1972   19816800   21899000
# 14               1973   20605000   22507000
# ...

# %%
macro = macro.rename(columns={'Home Sales Revenue': 'Period', 'Unnamed: 1': 'Median', 'Unnamed: 2': 'Average'})
macro = macro.iloc[1:]

# %%
macro = macro.rename(columns={'period': 'Period'})

# %%
macro = macro.set_index('Period')
macro
# Out:
# /Users/ryanandrade/opt/anaconda3/envs/DataScience/lib/python3.10/site-packages/pandas/core/indexes/base.py:6982: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   return Index(sequences[0], name=names)